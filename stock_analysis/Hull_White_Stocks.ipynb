# %%
# !pip install yfinance
# !pip install quantstats
# !pip install pyportfolioopt

# %% [markdown]
# We importing all necessary libraries and functions

# %%
#Hiding warnings
from logging import WARNING
import logging
logging.getLogger('matplotlib.font_manager').disabled = True

# Data handling and statistical analysis
import pandas as pd
from pandas_datareader import data
import numpy as np
from scipy import stats

# Data visualization
import matplotlib.pyplot as plt
import matplotlib.font_manager
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Optimization and allocation
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import black_litterman, BlackLittermanModel

# Financial data
import quantstats as qs
import yfinance as yf

# Linear Regression Model
from sklearn.linear_model import LinearRegression

# Enabling Plotly offline
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

# Datetime
import datetime as dt

#Neural network
import tensorflow as tf
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Stocks we want to analyze will be AstraZeneca, Intel, HSBC, McDonald's, Nike and Toyota. We selected one stocks from each industry because we want to try which industry was the best to investing through years.

# %%
azn = qs.utils.download_returns('AZN') #AstraZeneca
azn = azn.loc['2010-07-01':'2023-06-01']

intel = qs.utils.download_returns('INTC')
intel = intel.loc['2010-07-01':'2023-06-01']

hsbc = qs.utils.download_returns('HSBC')
hsbc = hsbc.loc['2010-07-01':'2023-06-01']

mcd = qs.utils.download_returns('MCD')#McDonald's
mcd = mcd.loc['2010-07-01':'2023-06-01']

nike = qs.utils.download_returns('NKE')
nike = nike.loc['2010-07-01':'2023-06-01']

tm = qs.utils.download_returns('TM') #Toyota
tm = tm.loc['2010-07-01':'2023-06-01']

# %%
azn.index = azn.index.tz_convert(None)
intel.index = intel.index.tz_convert(None)
hsbc.index = hsbc.index.tz_convert(None)
mcd.index = mcd.index.tz_convert(None)
nike.index = nike.index.tz_convert(None)
tm.index = tm.index.tz_convert(None)

# %% [markdown]
# Let's see how look like Daily Returns our stocks through whole period which we considering from 1st July 2010 to 1st June 2023

# %%
print('Astra Zeneca Daily Returns Plot:')
qs.plots.daily_returns(azn)

print('Intel Inc. Daily Returns Plot:')
qs.plots.daily_returns(intel)

print('HSBC Daily Returns Plot:')
qs.plots.daily_returns(hsbc)

print('''McDonald's Daily Returns Plot:''')
qs.plots.daily_returns(mcd)

print('''Nike Daily Returns Plot:''')
qs.plots.daily_returns(nike)

print('''Toyota Daily Returns Plot:''')
qs.plots.daily_returns(tm)
# Out:
# Astra Zeneca Daily Returns Plot:
# Intel Inc. Daily Returns Plot:
# HSBC Daily Returns Plot:
# McDonald's Daily Returns Plot:
# Nike Daily Returns Plot:
# Toyota Daily Returns Plot:

# %% [markdown]
# We can see that from our stocks Intel had the biggest volatility from about -15% to 20% changes in daily returns whereas Toyota stocks was the most stable where volatility was from -5% to 10% changes in daily returns

# %% [markdown]
# Let's also how look like Cumulative Returns all ours stocks.

# %%
# Plotting Cumulative Returns for each stock
print('\n')
print('\nAstra Zeneca Cumulative Returns Plot\n')
qs.plots.returns(azn)
print('\n')
print('\n')
print('\nIntel Cumulative Returns Plot\n')
qs.plots.returns(intel)
print('\n')
print('\n')
print('\nHSBC Cumulative Returns Plot\n')
qs.plots.returns(hsbc)
print('\n')
print('\n')
print('\nMcDonald Cumulative Returns Plot\n')
qs.plots.returns(mcd)
print('\n')
print('\n')
print('\nNike Cumulative Returns Plot\n')
qs.plots.returns(nike)
print('\n')
print('\n')
print('\nToyota Cumulative Returns Plot\n')
qs.plots.returns(tm)
# Out:
# Astra Zeneca Cumulative Returns Plot
# Intel Cumulative Returns Plot
# HSBC Cumulative Returns Plot
# McDonald Cumulative Returns Plot
# Nike Cumulative Returns Plot
# Toyota Cumulative Returns Plot

# %% [markdown]
# To see how look like volatility our stocks more clear we can use histograms to visualize it.

# %%
# Plotting histograms for daily returns
print('\n')
print('\nAstra Zeneca Daily Returns Histogram')
qs.plots.histogram(azn, resample = 'D')
print('\n')
print('\nIntel Daily Returns Histogram')
qs.plots.histogram(intel, resample = 'D')
print('\n')
print('\nHSBC Company Daily Returns Histogram')
qs.plots.histogram(hsbc, resample = 'D')
print('\n')
print('\nMcDonald Daily Returns Histogram')
qs.plots.histogram(mcd, resample = 'D')
print('\n')
print('\nNike Daily Returns Histogram')
qs.plots.histogram(nike, resample = 'D')
print('\n')
print('\nToyota Daily Returns Histogram')
qs.plots.histogram(tm, resample = 'D')
# Out:
# Astra Zeneca Daily Returns Histogram
# Intel Daily Returns Histogram
# HSBC Company Daily Returns Histogram
# McDonald Daily Returns Histogram
# Nike Daily Returns Histogram
# Toyota Daily Returns Histogram

# %% [markdown]
# We see that intel stock has the highest variance, while toyota stock is the most stable, which may mean that for someone who wants to take a conservative approach in the market, Toyota stock can play a big role because there is no high risk of volatility. Intel shares, on the other hand, can play a key role in an aggressive approach, as their high volatility risk can result in high profits but also large losses.

# %% [markdown]
# Let's see correlation between our stocks

# %%
#Analyzing data correlation
df = pd.concat([azn, intel, hsbc, mcd, nike, tm], join = 'outer', axis = 1)
df.columns = ['Astra', 'Intel', 'HSBC', 'McDonald','Nike','Toyota']
df
# Out:
#                         Astra     Intel      HSBC  McDonald      Nike  \
# Date
# 2010-07-01 04:00:00  0.008912 -0.010283  0.007019  0.012752  0.007698
# 2010-07-02 04:00:00 -0.010515 -0.002597 -0.004574 -0.008544 -0.003085
# 2010-07-06 04:00:00  0.015303  0.014583  0.014004 -0.000453 -0.009578
# 2010-07-07 04:00:00  0.011723  0.033880  0.015106  0.018151  0.020086
# 2010-07-08 04:00:00  0.009104 -0.001985  0.009566  0.025405  0.025088
# ...                       ...       ...       ...       ...       ...
# 2023-05-25 04:00:00 -0.008425 -0.055172  0.010215 -0.001399 -0.007480
# 2023-05-26 04:00:00  0.010168  0.058394  0.006386  0.001821  0.000279
# 2023-05-30 04:00:00 -0.015030  0.034138 -0.010576 -0.003915 -0.009208
# 2023-05-31 04:00:00  0.023100  0.048349 -0.016034  0.000667 -0.011829
# 2023-06-01 04:00:00 -0.003284 -0.009860  0.016295  0.009681 -0.015486
#
#                        Toyota
# Date
# 2010-07-01 04:00:00  0.001896
# 2010-07-02 04:00:00 -0.006405
# 2010-07-06 04:00:00  0.025930
# 2010-07-07 04:00:00  0.013851
# 2010-07-08 04:00:00  0.002958
# ...                       ...
# 2023-05-25 04:00:00  0.001938
# 2023-05-26 04:00:00  0.003438
# 2023-05-30 04:00:00 -0.016776
# 2023-05-31 04:00:00 -0.011617
# 2023-06-01 04:00:00  0.033203
#
# [3252 rows x 6 columns]

# %%
# Correlation Matrix
corr = df.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, annot=True, mask = mask)
plt.show()
# Out:
# <ipython-input-58-308565ed2970>:3: DeprecationWarning:
#
# `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# It means that the biggest correlation is between HSBC and Toyota shares. The lowest correlation appears between Nike and AstraZeneca

# %% [markdown]
# #Making a portfolio

# %% [markdown]
# We create initial portfolio with initial values for each shares

# %%
weights = [0.17, 0.17, 0.17, 0.17, 0.16, 0.16]
portfolio = azn*weights[0] + intel*weights[1] + hsbc*weights[2] + mcd*weights[3] + nike*weights[4] + tm*weights[5]
portfolio
# Out:
# Date
# 2010-07-01 04:00:00    0.004663
# 2010-07-02 04:00:00   -0.005978
# 2010-07-06 04:00:00    0.010001
# 2010-07-07 04:00:00    0.018836
# 2010-07-08 04:00:00    0.011643
#                          ...
# 2023-05-25 04:00:00   -0.010200
# 2023-05-26 04:00:00    0.013646
# 2023-05-30 04:00:00   -0.003373
# 2023-05-31 04:00:00    0.005783
# 2023-06-01 04:00:00    0.005016
# Name: Close, Length: 3252, dtype: float64

# %% [markdown]
# And now we create report where we compare our portfolio to american benchmark sp500 to see performane of this portfolio.

# %%
# Data from sp500, american benchmark
sp500 = qs.utils.download_returns( '^GSPC' )
sp500 = sp500.loc[ '2010-07-01' : '2023-06-01' ]
sp500.index = sp500 .index.tz_convert(None)

# %%
#report about our initial portfolio performance
qs.reports.full(portfolio, benchmark = sp500)
# Out:
# [Performance Metrics]
#
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2010-07-01  2010-07-01
# End Period                 2023-06-01  2023-06-01
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      100.0%
#
# Cumulative Return          339.39%     309.53%
# CAGR﹪                     12.13%      11.52%
#
# Sharpe                     0.77        0.71
# Prob. Sharpe Ratio         99.66%      99.4%
# Smart Sharpe               0.68        0.63
# Sortino                    1.08        0.99
# Smart Sortino              0.96        0.88
# Sortino/√2                 0.76        0.7
# Smart Sortino/√2           0.68        0.63
# Omega                      1.15        1.15
#
# Max Drawdown               -29.22%     -33.92%
# Longest DD Days            498         512
# Volatility (ann.)          16.86%      17.62%
# R^2                        0.76        0.76
# Information Ratio          0.0         0.0
# Calmar                     0.42        0.34
# Skew                       -0.51       -0.5
# Kurtosis                   11.03       12.77
#
# Expected Daily %           0.05%       0.04%
# Expected Monthly %         0.95%       0.91%
# Expected Yearly %          11.15%      10.59%
# Kelly Criterion            5.39%       5.45%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -1.7%       -1.78%
# Expected Shortfall (cVaR)  -1.7%       -1.78%
#
# Max Consecutive Wins       12          8
# Max Consecutive Losses     9           9
# Gain/Pain Ratio            0.15        0.15
# Gain/Pain (1M)             1.03        0.91
#
# Payoff Ratio               0.96        0.94
# Profit Factor              1.15        1.15
# Common Sense Ratio         1.15        1.09
# CPC Index                  0.59        0.58
# Tail Ratio                 1.0         0.96
# Outlier Win Ratio          3.75        3.8
# Outlier Loss Ratio         4.1         4.05
#
# MTD                        0.5%        0.99%
# 3M                         6.7%        6.32%
# 6M                         6.97%       3.45%
# YTD                        9.87%       9.94%
# 1Y                         -0.34%      2.15%
# 3Y (ann.)                  9.38%       11.16%
# 5Y (ann.)                  8.28%       9.36%
# 10Y (ann.)                 10.69%      9.98%
# All-time (ann.)            12.13%      11.52%
#
# Best Day                   9.04%       9.38%
# Worst Day                  -11.5%      -11.98%
# Best Month                 11.24%      12.68%
# Worst Month                -14.85%     -12.51%
# Best Year                  31.12%      29.6%
# Worst Year                 -13.19%     -19.44%
#
# Avg. Drawdown              -2.03%      -1.75%
# Avg. Drawdown Days         22          18
# Recovery Factor            11.61       9.12
# Ulcer Index                0.06        0.07
# Serenity Index             4.56        3.61
#
# Avg. Up Month              3.55%       3.49%
# Avg. Down Month            -3.63%      -3.9%
# Win Days %                 53.63%      54.17%
# Win Month %                62.82%      66.67%
# Win Quarter %              71.15%      76.92%
# Win Year %                 85.71%      71.43%
#
# Beta                       0.84        -
# Alpha                      0.02        -
# Correlation                87.37%      -
# Treynor Ratio              405.96%     -
#
#
#
# [5 Worst Drawdowns]
#
#     Start       Valley      End           Days    Max Drawdown    99% Max Drawdown
# --  ----------  ----------  ----------  ------  --------------  ------------------
#  1  2022-01-18  2022-09-30  2023-06-01     498          -29.22              -27.89
#  2  2020-02-13  2020-03-16  2020-12-04     295          -28.29              -26.13
#  3  2015-12-30  2016-02-11  2016-09-02     246          -15.10              -14.49
#  4  2015-05-22  2015-08-25  2015-10-22     153          -13.26              -11.06
#  5  2011-07-08  2011-08-10  2012-01-19     195          -13.17              -12.71
#
#
#
# [Strategy Visualization]
# via Matplotlib
# /usr/local/lib/python3.10/dist-packages/quantstats/stats.py:968: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.

# %% [markdown]
# Now let's try to opmtize our portfolio in two different approaches and check which will be better option to gain better results.

# %%
azn_df = yf.download('AZN', start = '2010-07-01', end = '2023-06-02')
intel_df = yf.download('INTC', start = '2010-07-01', end = '2023-06-02')
hsbc_df = yf.download('HSBC', start = '2010-07-01', end = '2023-06-02')
mcd_df = yf.download('MCD', start = '2010-07-01', end = '2023-06-02')
nike_df = yf.download('NKE', start = '2010-07-01', end = '2023-06-02')
tm_df = yf.download('TM', start = '2010-07-01', end = '2023-06-02')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# We will be using Adjusted Close prices to our analysis

# %%
# Extracting Adjusted Close for each stock
azn_df = azn_df['Adj Close']
intel_df = intel_df['Adj Close']
hsbc_df = hsbc_df['Adj Close']
mcd_df = mcd_df['Adj Close']
nike_df = nike_df['Adj Close']
tm_df = tm_df['Adj Close']

# %%
adj = pd.concat([azn_df, intel_df, hsbc_df, mcd_df, nike_df, tm_df], join = 'outer', axis = 1)
adj.columns = ['Astra', 'Intel', 'HSBC', 'McDonald','Nike','Toyota']
adj
# Out:
#                 Astra      Intel       HSBC    McDonald        Nike  \
# Date
# 2010-07-01  13.991046  12.910232  23.893373   46.460941   14.594629
# 2010-07-02  13.843925  12.876705  23.784081   46.063957   14.549604
# 2010-07-06  14.055781  13.064492  24.117159   46.043068   14.410242
# 2010-07-07  14.220551  13.507122  24.481461   46.878807   14.699687
# 2010-07-08  14.350019  13.480297  24.715654   48.069763   15.068463
# ...               ...        ...        ...         ...         ...
# 2023-05-25  71.790001  27.400000  37.580002  284.012390  107.127373
# 2023-05-26  72.519997  29.000000  37.820000  284.529663  107.157272
# 2023-05-30  71.430000  29.990000  37.419998  283.415588  106.170517
# 2023-05-31  73.080002  31.440001  36.820000  283.604553  104.914658
# 2023-06-01  72.839996  31.129999  37.419998  286.350006  103.290001
#
#                 Toyota
# Date
# 2010-07-01   58.906277
# 2010-07-02   58.529003
# 2010-07-06   60.046665
# 2010-07-07   60.878399
# 2010-07-08   61.058464
# ...                ...
# 2023-05-25  139.600006
# 2023-05-26  140.080002
# 2023-05-30  137.729996
# 2023-05-31  136.130005
# 2023-06-01  140.649994
#
# [3252 rows x 6 columns]

# %% [markdown]
# #Mean-Variance Optimalization model

# %% [markdown]
# To optimalize our portfolio using mean-variance model we need to create covariance matrix of our data frame and also calculate expected returns.

# %%
# Calculating parameters required to Mean-Variance model
mu = expected_returns.mean_historical_return(adj) #expected returns
S = risk_models.sample_cov(adj) #Covariance matrix

# %% [markdown]
# Covariance Matrix

# %%
S
# Out:
#              Astra     Intel      HSBC  McDonald      Nike    Toyota
# Astra     0.056528  0.021795  0.019790  0.014525  0.019134  0.016793
# Intel     0.021795  0.089579  0.027904  0.020544  0.032741  0.026058
# HSBC      0.019790  0.027904  0.060212  0.016769  0.024810  0.026477
# McDonald  0.014525  0.020544  0.016769  0.035766  0.023239  0.015626
# Nike      0.019134  0.032741  0.024810  0.023239  0.075988  0.024110
# Toyota    0.016793  0.026058  0.026477  0.015626  0.024110  0.046416

# %% [markdown]
# We try to optimize portfolio for person who has conservative approach, so we want to minimalize volatility of our stocks. We using to this min_volatility() function

# %%
# Optimizing for minimal volatility
ef = EfficientFrontier(mu, S) # Providing expected returns and covariance matrix as input
new_weights = ef.min_volatility() # Optimizing weights for minimal volatility

clean_weights = ef.clean_weights() # clean_weights rounds the weights and clips near-zeros

clean_weights
# Out:
# OrderedDict([('Astra', 0.20323),
#              ('Intel', 0.01798),
#              ('HSBC', 0.10023),
#              ('McDonald', 0.42442),
#              ('Nike', 0.02708),
#              ('Toyota', 0.22707)])

# %% [markdown]
# We see that the model took the most shares for McDonalds and the least for Intel. Our initial analysis also found Intel to be the most volatile and McDonalds to be one of the least volatile, so it looks like our model worked.

# %% [markdown]
# Let's create new portflio with new weights and check whether it have better return than out initail portfolio

# %%
cons_weights = [0.20323, 0.01798, 0.10023, 0.42442, 0.02708, 0.22707]
cons_portfolio = azn*cons_weights[0] + intel*cons_weights[1] + hsbc*cons_weights[2] + mcd*cons_weights[3] + nike*cons_weights[4] + tm*cons_weights[5]
cons_portfolio
# Out:
# Date
# 2010-07-01 04:00:00    0.008381
# 2010-07-02 04:00:00   -0.007806
# 2010-07-06 04:00:00    0.010212
# 2010-07-07 04:00:00    0.015899
# 2010-07-08 04:00:00    0.014907
#                          ...
# 2023-05-25 04:00:00   -0.002037
# 2023-05-26 04:00:00    0.005318
# 2023-05-30 04:00:00   -0.009221
# 2023-05-31 04:00:00    0.001282
# 2023-06-01 04:00:00    0.012017
# Name: Close, Length: 3252, dtype: float64

# %%
#report about our conservative portfolio performance
qs.reports.full(cons_portfolio, benchmark = sp500)
# Out:
# [Performance Metrics]
#
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2010-07-01  2010-07-01
# End Period                 2023-06-01  2023-06-01
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      100.0%
#
# Cumulative Return          381.49%     309.53%
# CAGR﹪                     12.93%      11.52%
#
# Sharpe                     0.86        0.71
# Prob. Sharpe Ratio         99.88%      99.4%
# Smart Sharpe               0.76        0.63
# Sortino                    1.22        0.99
# Smart Sortino              1.08        0.88
# Sortino/√2                 0.86        0.7
# Smart Sortino/√2           0.77        0.62
# Omega                      1.17        1.17
#
# Max Drawdown               -28.66%     -33.92%
# Longest DD Days            440         512
# Volatility (ann.)          15.61%      17.62%
# R^2                        0.65        0.65
# Information Ratio          0.01        0.01
# Calmar                     0.45        0.34
# Skew                       -0.48       -0.5
# Kurtosis                   15.94       12.77
#
# Expected Daily %           0.05%       0.04%
# Expected Monthly %         1.01%       0.91%
# Expected Yearly %          11.88%      10.59%
# Kelly Criterion            5.87%       4.86%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -1.56%      -1.78%
# Expected Shortfall (cVaR)  -1.56%      -1.78%
#
# Max Consecutive Wins       11          8
# Max Consecutive Losses     10          9
# Gain/Pain Ratio            0.17        0.15
# Gain/Pain (1M)             1.3         0.91
#
# Payoff Ratio               0.95        0.93
# Profit Factor              1.17        1.15
# Common Sense Ratio         1.21        1.09
# CPC Index                  0.6         0.58
# Tail Ratio                 1.03        0.96
# Outlier Win Ratio          3.9         3.64
# Outlier Loss Ratio         4.31        3.92
#
# MTD                        1.2%        0.99%
# 3M                         7.45%       6.32%
# 6M                         6.11%       3.45%
# YTD                        9.54%       9.94%
# 1Y                         7.34%       2.15%
# 3Y (ann.)                  15.32%      11.16%
# 5Y (ann.)                  12.45%      9.36%
# 10Y (ann.)                 11.67%      9.98%
# All-time (ann.)            12.93%      11.52%
#
# Best Day                   10.9%       9.38%
# Worst Day                  -11.64%     -11.98%
# Best Month                 11.06%      12.68%
# Worst Month                -11.42%     -12.51%
# Best Year                  33.11%      29.6%
# Worst Year                 -2.83%      -19.44%
#
# Avg. Drawdown              -1.89%      -1.75%
# Avg. Drawdown Days         21          18
# Recovery Factor            13.31       9.12
# Ulcer Index                0.05        0.07
# Serenity Index             9.32        3.61
#
# Avg. Up Month              3.18%       3.44%
# Avg. Down Month            -3.28%      -4.01%
# Win Days %                 54.09%      54.17%
# Win Month %                66.67%      66.67%
# Win Quarter %              75.0%       76.92%
# Win Year %                 92.86%      71.43%
#
# Beta                       0.71        -
# Alpha                      0.05        -
# Correlation                80.43%      -
# Treynor Ratio              535.54%     -
#
#
#
# [5 Worst Drawdowns]
#
#     Start       Valley      End           Days    Max Drawdown    99% Max Drawdown
# --  ----------  ----------  ----------  ------  --------------  ------------------
#  1  2020-02-13  2020-03-23  2020-11-10     271          -28.66              -27.06
#  2  2022-01-14  2022-09-30  2023-03-31     440          -18.60              -17.11
#  3  2015-04-27  2015-08-25  2015-10-22     178          -12.19              -10.52
#  4  2012-04-04  2012-06-04  2012-12-11     251          -11.97              -11.43
#  5  2011-07-25  2011-09-22  2012-01-18     177          -11.29              -10.87
#
#
#
# [Strategy Visualization]
# via Matplotlib
# /usr/local/lib/python3.10/dist-packages/quantstats/stats.py:968: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.

# %% [markdown]
# We see that conservative approach has lower volatility and better cumulative return than initial portfolio

# %% [markdown]
# Now we try to optimize portfolio for person who has aggressive approach

# %% [markdown]
# To do this first we need to check how look like our volatility for each stocks

# %%
Volatility = {'Astra': qs.stats.volatility(azn), 'Intel':qs.stats.volatility(intel), 'HSBC': qs.stats.volatility(hsbc),
              'McDonalds': qs.stats.volatility(mcd), 'Nike': qs.stats.volatility(nike),'Toyota': qs.stats.volatility(tm)}
Volatility
# Out:
# {'Astra': 0.23773008034204596,
#  'Intel': 0.29926661581873154,
#  'HSBC': 0.24535006651313998,
#  'McDonalds': 0.18912106922923003,
#  'Nike': 0.2756239965034083,
#  'Toyota': 0.215410083291047}

# %% [markdown]
# Intel has the biggest volatility of our conider stocks. McDonald's has the lowest volatility.

# %%
# Optimizing for maximal return for given target risk
ef = EfficientFrontier(mu, S) # Providing expected returns and covariance matrix as input
new_weights = ef.efficient_risk(0.22) # Optimizing weights for Sharpe ratio maximization

clean_weights = ef.clean_weights() # clean_weights rounds the weights and clips near-zeros

clean_weights
# Out:
# OrderedDict([('Astra', 0.0),
#              ('Intel', 0.0),
#              ('HSBC', 0.0),
#              ('McDonald', 0.32812),
#              ('Nike', 0.67188),
#              ('Toyota', 0.0)])

# %% [markdown]
# Due to the adopted higher volatility threshold (+50% volatility from prevoius approach), our model estimated to take into account a larger number of Nike stocks to maximize the return

# %%
aggr_weights = [0.328112, 0.67188]
aggr_portfolio = mcd*aggr_weights[0]+nike*aggr_weights[1]
aggr_portfolio
# Out:
# Date
# 2010-07-01 04:00:00    0.009356
# 2010-07-02 04:00:00   -0.004876
# 2010-07-06 04:00:00   -0.006584
# 2010-07-07 04:00:00    0.019451
# 2010-07-08 04:00:00    0.025191
#                          ...
# 2023-05-25 04:00:00   -0.005485
# 2023-05-26 04:00:00    0.000785
# 2023-05-30 04:00:00   -0.007472
# 2023-05-31 04:00:00   -0.007729
# 2023-06-01 04:00:00   -0.007228
# Name: Close, Length: 3252, dtype: float64

# %%
#report about our aggresive portfolio performance
qs.reports.full(aggr_portfolio, benchmark = sp500)
# Out:
# [Performance Metrics]
#
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2010-07-01  2010-07-01
# End Period                 2023-06-01  2023-06-01
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      100.0%
#
# Cumulative Return          648.15%     309.53%
# CAGR﹪                     16.85%      11.52%
#
# Sharpe                     0.82        0.71
# Prob. Sharpe Ratio         99.84%      99.4%
# Smart Sharpe               0.77        0.67
# Sortino                    1.21        0.99
# Smart Sortino              1.14        0.93
# Sortino/√2                 0.86        0.7
# Smart Sortino/√2           0.81        0.66
# Omega                      1.17        1.17
#
# Max Drawdown               -40.36%     -33.92%
# Longest DD Days            569         512
# Volatility (ann.)          22.0%       17.62%
# R^2                        0.51        0.51
# Information Ratio          0.02        0.02
# Calmar                     0.42        0.34
# Skew                       0.32        -0.5
# Kurtosis                   14.25       12.77
#
# Expected Daily %           0.06%       0.04%
# Expected Monthly %         1.3%        0.91%
# Expected Yearly %          15.46%      10.59%
# Kelly Criterion            5.77%       5.06%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -2.21%      -1.78%
# Expected Shortfall (cVaR)  -2.21%      -1.78%
#
# Max Consecutive Wins       9           8
# Max Consecutive Losses     9           9
# Gain/Pain Ratio            0.17        0.15
# Gain/Pain (1M)             1.0         0.91
#
# Payoff Ratio               1.01        0.93
# Profit Factor              1.17        1.15
# Common Sense Ratio         1.18        1.09
# CPC Index                  0.62        0.58
# Tail Ratio                 1.01        0.96
# Outlier Win Ratio          3.5         4.63
# Outlier Loss Ratio         3.89        4.72
#
# MTD                        -0.72%      0.99%
# 3M                         -5.81%      6.32%
# 6M                         -1.07%      3.45%
# YTD                        -4.56%      9.94%
# 1Y                         -2.01%      2.15%
# 3Y (ann.)                  8.99%       11.16%
# 5Y (ann.)                  10.48%      9.36%
# 10Y (ann.)                 15.1%       9.98%
# All-time (ann.)            16.85%      11.52%
#
# Best Day                   16.14%      9.38%
# Worst Day                  -13.02%     -11.98%
# Best Month                 13.75%      12.68%
# Worst Month                -17.4%      -12.51%
# Best Year                  40.29%      29.6%
# Worst Year                 -19.17%     -19.44%
#
# Avg. Drawdown              -2.67%      -1.75%
# Avg. Drawdown Days         23          18
# Recovery Factor            16.06       9.12
# Ulcer Index                0.1         0.07
# Serenity Index             5.2         3.61
#
# Avg. Up Month              5.05%       3.6%
# Avg. Down Month            -4.83%      -4.26%
# Win Days %                 52.58%      54.17%
# Win Month %                62.18%      66.67%
# Win Quarter %              71.15%      76.92%
# Win Year %                 78.57%      71.43%
#
# Beta                       0.89        -
# Alpha                      0.07        -
# Correlation                71.17%      -
# Treynor Ratio              729.51%     -
#
#
#
# [5 Worst Drawdowns]
#
#     Start       Valley      End           Days    Max Drawdown    99% Max Drawdown
# --  ----------  ----------  ----------  ------  --------------  ------------------
#  1  2021-11-08  2022-09-30  2023-06-01     569          -40.36              -37.46
#  2  2020-02-18  2020-03-23  2020-08-10     173          -38.17              -33.84
#  3  2012-05-03  2012-06-29  2013-03-06     307          -18.30              -17.21
#  4  2016-03-23  2016-11-03  2017-06-30     464          -18.19              -17.49
#  5  2010-12-22  2011-03-22  2011-06-28     187          -13.18              -12.15
#
#
#
# [Strategy Visualization]
# via Matplotlib
# /usr/local/lib/python3.10/dist-packages/quantstats/stats.py:968: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.

# %% [markdown]
# Let's compare two consider approach

# %%
#comparison aggresive approach with conservative approach
qs.reports.full(aggr_portfolio, cons_portfolio)
# Out:
# [Performance Metrics]
#
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2010-07-01  2010-07-01
# End Period                 2023-06-01  2023-06-01
# Risk-Free Rate             0.0%        0.0%
# Time in Market             100.0%      100.0%
#
# Cumulative Return          648.15%     381.49%
# CAGR﹪                     16.85%      12.93%
#
# Sharpe                     0.82        0.86
# Prob. Sharpe Ratio         99.84%      99.88%
# Smart Sharpe               0.77        0.81
# Sortino                    1.21        1.22
# Smart Sortino              1.14        1.15
# Sortino/√2                 0.86        0.86
# Smart Sortino/√2           0.81        0.81
# Omega                      1.17        1.17
#
# Max Drawdown               -40.36%     -28.66%
# Longest DD Days            569         440
# Volatility (ann.)          22.0%       15.61%
# R^2                        0.5         0.5
# Information Ratio          0.02        0.02
# Calmar                     0.42        0.45
# Skew                       0.32        -0.48
# Kurtosis                   14.25       15.94
#
# Expected Daily %           0.06%       0.05%
# Expected Monthly %         1.3%        1.01%
# Expected Yearly %          15.46%      11.88%
# Kelly Criterion            5.96%       6.39%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -2.21%      -1.56%
# Expected Shortfall (cVaR)  -2.21%      -1.56%
#
# Max Consecutive Wins       9           11
# Max Consecutive Losses     9           10
# Gain/Pain Ratio            0.17        0.17
# Gain/Pain (1M)             1.0         1.3
#
# Payoff Ratio               1.02        0.96
# Profit Factor              1.17        1.17
# Common Sense Ratio         1.18        1.21
# CPC Index                  0.62        0.61
# Tail Ratio                 1.01        1.03
# Outlier Win Ratio          3.38        4.78
# Outlier Loss Ratio         3.58        4.77
#
# MTD                        -0.72%      1.2%
# 3M                         -5.81%      7.45%
# 6M                         -1.07%      6.11%
# YTD                        -4.56%      9.54%
# 1Y                         -2.01%      7.34%
# 3Y (ann.)                  8.99%       15.32%
# 5Y (ann.)                  10.48%      12.45%
# 10Y (ann.)                 15.1%       11.67%
# All-time (ann.)            16.85%      12.93%
#
# Best Day                   16.14%      10.9%
# Worst Day                  -13.02%     -11.64%
# Best Month                 13.75%      11.06%
# Worst Month                -17.4%      -11.42%
# Best Year                  40.29%      33.11%
# Worst Year                 -19.17%     -2.83%
#
# Avg. Drawdown              -2.67%      -1.89%
# Avg. Drawdown Days         23          21
# Recovery Factor            16.06       13.31
# Ulcer Index                0.1         0.05
# Serenity Index             5.2         9.32
#
# Avg. Up Month              5.0%        3.23%
# Avg. Down Month            -4.79%      -3.29%
# Win Days %                 52.58%      54.09%
# Win Month %                62.18%      66.67%
# Win Quarter %              71.15%      75.0%
# Win Year %                 78.57%      92.86%
#
# Beta                       1.0         -
# Alpha                      0.05        -
# Correlation                70.95%      -
# Treynor Ratio              648.15%     -
#
#
#
# [5 Worst Drawdowns]
#
#     Start       Valley      End           Days    Max Drawdown    99% Max Drawdown
# --  ----------  ----------  ----------  ------  --------------  ------------------
#  1  2021-11-08  2022-09-30  2023-06-01     569          -40.36              -37.46
#  2  2020-02-18  2020-03-23  2020-08-10     173          -38.17              -33.84
#  3  2012-05-03  2012-06-29  2013-03-06     307          -18.30              -17.21
#  4  2016-03-23  2016-11-03  2017-06-30     464          -18.19              -17.49
#  5  2010-12-22  2011-03-22  2011-06-28     187          -13.18              -12.15
#
#
#
# [Strategy Visualization]
# via Matplotlib
# /usr/local/lib/python3.10/dist-packages/quantstats/stats.py:968: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.

# %% [markdown]
# That means, aggerisve approach has better cumulative returns than conservative approach

# %% [markdown]
# #Neural network

# %% [markdown]
# Dividing data into train and test subset in proporion 80:20

# %%
azn_train = azn_df[0:2600]
intel_train = intel_df[0:2600]
hsbc_train = hsbc_df[0:2600]
mcd_train = mcd_df[0:2600]
nike_train = nike_df[0:2600]
tm_train = tm_df[0:2600]

azn_test = azn_df[2601:]
intel_test = intel_df[2601:]
hsbc_test = hsbc_df[2601:]
mcd_test = mcd_df[2601:]
nike_test = nike_df[2601:]
tm_test = tm_df[2601:]

# %% [markdown]
# Creating function to divide data into subset X and Y

# %%
def genXY(shares, seq_len):
        """
        Generates training and test data
        :param seq_len: length of window
        :return: Transform data to X and Y subset
        """
        pom_X=[]
        pom_Y=[]
        X=[]
        Y=[]
        for i in range((len(shares)//seq_len)*seq_len - seq_len - 1):
            x = np.array(shares[i: i + seq_len])
            y = np.array([shares[i + seq_len + 1]], np.float64)
            pom_X.append(x)
            pom_Y.append(y)
        X = np.array(pom_X) /300
        Y = np.array(pom_Y) /300
        return X, Y

# %% [markdown]
# Train and test sets

# %%
X_train_azn, Y_train_azn = genXY(azn_train, 10)
X_train_intel, Y_train_intel = genXY(intel_train, 10)
X_train_hsbc, Y_train_hsbc = genXY(hsbc_train, 10)
X_train_mcd, Y_train_mcd = genXY(mcd_train, 10)
X_train_nike, Y_train_nike = genXY(nike_train, 10)
X_train_tm, Y_train_tm = genXY(tm_train, 10)

X_test_azn, Y_test_azn = genXY(azn_test, 10)
X_test_intel, Y_test_intel = genXY(intel_test, 10)
X_test_hsbc, Y_test_hsbc = genXY(hsbc_test, 10)
X_test_mcd, Y_test_mcd = genXY(mcd_test, 10)
X_test_nike, Y_test_nike = genXY(nike_test, 10)
X_test_tm, Y_test_tm = genXY(tm_test, 10)

# %% [markdown]
# ##Multilayer perception

# %%
MLP = tf.keras.models.Sequential()
MLP.add(tf.keras.layers.Dense(100, activation=tf.nn.relu))
MLP.add(tf.keras.layers.Dense(100, activation=tf.nn.relu))
MLP.add(tf.keras.layers.Dense(1, activation=tf.nn.relu))

MLP.compile(optimizer="adam", loss="mean_squared_error")

# %%
MLP.fit(X_train_azn, Y_train_azn, epochs=100)
MLP.evaluate(X_test_azn, Y_test_azn)

X_predict_azn,Y_predict = genXY(azn_df,10)
X_mlp_azn = MLP.predict(X_predict_azn)*300
# Out:
# Epoch 1/100
# 81/81 [==============================] - 1s 2ms/step - loss: 2.2021e-04
# Epoch 2/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.8119e-06
# Epoch 3/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.3625e-06
# Epoch 4/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.6820e-06
# Epoch 5/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.2683e-06
# Epoch 6/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.1990e-06
# Epoch 7/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.0878e-06
# Epoch 8/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.9905e-06
# Epoch 9/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.1791e-06
# Epoch 10/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3611e-06
# Epoch 11/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3093e-06
# Epoch 12/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.4494e-06
# Epoch 13/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.7760e-06
# Epoch 14/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3453e-06
# Epoch 15/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5940e-06
# Epoch 16/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9632e-06
# Epoch 17/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7875e-06
# Epoch 18/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0478e-06
# Epoch 19/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.4111e-06
# Epoch 20/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.2755e-06
# Epoch 21/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0802e-06
# Epoch 22/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.7897e-06
# Epoch 23/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1440e-06
# Epoch 24/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.9024e-06
# Epoch 25/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.4861e-06
# Epoch 26/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6302e-06
# Epoch 27/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7852e-06
# Epoch 28/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.9657e-06
# Epoch 29/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9088e-06
# Epoch 30/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.9257e-06
# Epoch 31/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3472e-06
# Epoch 32/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4812e-06
# Epoch 33/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.6038e-06
# Epoch 34/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3665e-06
# Epoch 35/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.4549e-06
# Epoch 36/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.8677e-06
# Epoch 37/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6691e-06
# Epoch 38/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.7575e-06
# Epoch 39/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1933e-06
# Epoch 40/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.2808e-06
# Epoch 41/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4021e-06
# Epoch 42/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.2350e-06
# Epoch 43/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8138e-06
# Epoch 44/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.3785e-06
# Epoch 45/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3957e-06
# Epoch 46/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.5093e-06
# Epoch 47/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5025e-06
# Epoch 48/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3018e-06
# Epoch 49/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3829e-06
# Epoch 50/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.0023e-06
# Epoch 51/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.2127e-06
# Epoch 52/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3007e-06
# Epoch 53/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1464e-06
# Epoch 54/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.9260e-06
# Epoch 55/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0129e-06
# Epoch 56/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0566e-06
# Epoch 57/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9542e-06
# Epoch 58/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.7458e-06
# Epoch 59/100
# 81/81 [==============================] - 0s 3ms/step - loss: 6.5337e-06
# Epoch 60/100
# 81/81 [==============================] - 0s 3ms/step - loss: 6.1394e-06
# Epoch 61/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.2290e-06
# Epoch 62/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.7201e-06
# Epoch 63/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.5366e-06
# Epoch 64/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.8072e-06
# Epoch 65/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.2884e-06
# Epoch 66/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.5556e-06
# Epoch 67/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.2672e-06
# Epoch 68/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.7665e-06
# Epoch 69/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.9810e-06
# Epoch 70/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.9310e-06
# Epoch 71/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.2767e-06
# Epoch 72/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.6058e-06
# Epoch 73/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.9031e-06
# Epoch 74/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3340e-06
# Epoch 75/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.1197e-06
# Epoch 76/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1631e-06
# Epoch 77/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.2404e-06
# Epoch 78/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4328e-06
# Epoch 79/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5025e-06
# Epoch 80/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6975e-06
# Epoch 81/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9245e-06
# Epoch 82/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6546e-06
# Epoch 83/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.8644e-06
# Epoch 84/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.0990e-06
# Epoch 85/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7992e-06
# Epoch 86/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.0549e-06
# Epoch 87/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3525e-06
# Epoch 88/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4342e-06
# Epoch 89/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.0004e-06
# Epoch 90/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.2514e-06
# Epoch 91/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6566e-06
# Epoch 92/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3555e-06
# Epoch 93/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.2014e-06
# Epoch 94/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5418e-06
# Epoch 95/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7269e-06
# Epoch 96/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1778e-06
# Epoch 97/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4324e-06
# Epoch 98/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5834e-06
# Epoch 99/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.0937e-06
# Epoch 100/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6322e-06
# 20/20 [==============================] - 0s 2ms/step - loss: 2.4225e-05
# 102/102 [==============================] - 0s 1ms/step

# %%
MLP.fit(X_train_intel, Y_train_intel, epochs=100)
MLP.evaluate(X_test_intel, Y_test_intel)

X_predict_intel,Y_predict = genXY(intel_df,10)
X_mlp_intel = MLP.predict(X_predict_intel)*300
# Out:
# Epoch 1/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.2659e-05
# Epoch 2/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.3296e-05
# Epoch 3/100
# 81/81 [==============================] - 0s 3ms/step - loss: 1.1562e-05
# Epoch 4/100
# 81/81 [==============================] - 1s 7ms/step - loss: 1.1632e-05
# Epoch 5/100
# 81/81 [==============================] - 1s 9ms/step - loss: 1.3081e-05
# Epoch 6/100
# 81/81 [==============================] - 0s 5ms/step - loss: 9.9553e-06
# Epoch 7/100
# 81/81 [==============================] - 1s 8ms/step - loss: 1.0598e-05
# Epoch 8/100
# 81/81 [==============================] - 1s 8ms/step - loss: 1.1202e-05
# Epoch 9/100
# 81/81 [==============================] - 0s 6ms/step - loss: 9.8967e-06
# Epoch 10/100
# 81/81 [==============================] - 0s 4ms/step - loss: 1.0683e-05
# Epoch 11/100
# 81/81 [==============================] - 1s 13ms/step - loss: 1.2228e-05
# Epoch 12/100
# 81/81 [==============================] - 1s 14ms/step - loss: 1.0127e-05
# Epoch 13/100
# 81/81 [==============================] - 1s 8ms/step - loss: 9.5056e-06
# Epoch 14/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.9485e-06
# Epoch 15/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.9191e-06
# Epoch 16/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.8384e-06
# Epoch 17/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0765e-05
# Epoch 18/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.0225e-06
# Epoch 19/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0207e-05
# Epoch 20/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.4706e-06
# Epoch 21/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0896e-05
# Epoch 22/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.3241e-06
# Epoch 23/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0133e-05
# Epoch 24/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.5089e-06
# Epoch 25/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.1864e-05
# Epoch 26/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.7565e-06
# Epoch 27/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0124e-05
# Epoch 28/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.6595e-06
# Epoch 29/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0066e-05
# Epoch 30/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0198e-05
# Epoch 31/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.9988e-06
# Epoch 32/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0555e-05
# Epoch 33/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.0733e-06
# Epoch 34/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.9777e-06
# Epoch 35/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0991e-05
# Epoch 36/100
# 81/81 [==============================] - 1s 7ms/step - loss: 1.0338e-05
# Epoch 37/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0830e-05
# Epoch 38/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.4513e-06
# Epoch 39/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.0759e-06
# Epoch 40/100
# 81/81 [==============================] - 1s 6ms/step - loss: 9.8278e-06
# Epoch 41/100
# 81/81 [==============================] - 0s 3ms/step - loss: 8.6115e-06
# Epoch 42/100
# 81/81 [==============================] - 0s 2ms/step - loss: 8.6780e-06
# Epoch 43/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.1936e-05
# Epoch 44/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0321e-05
# Epoch 45/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0156e-05
# Epoch 46/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.9914e-06
# Epoch 47/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.0000e-06
# Epoch 48/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.9723e-06
# Epoch 49/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.8809e-06
# Epoch 50/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.9481e-06
# Epoch 51/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.5609e-06
# Epoch 52/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0441e-05
# Epoch 53/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0259e-05
# Epoch 54/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0058e-05
# Epoch 55/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.0333e-06
# Epoch 56/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0236e-05
# Epoch 57/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.3822e-06
# Epoch 58/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0689e-05
# Epoch 59/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0167e-05
# Epoch 60/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.2232e-06
# Epoch 61/100
# 81/81 [==============================] - 0s 2ms/step - loss: 8.7846e-06
# Epoch 62/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.6746e-06
# Epoch 63/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.7912e-06
# Epoch 64/100
# 81/81 [==============================] - 0s 2ms/step - loss: 8.6744e-06
# Epoch 65/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.1756e-05
# Epoch 66/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.5514e-06
# Epoch 67/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.2245e-06
# Epoch 68/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.4053e-06
# Epoch 69/100
# 81/81 [==============================] - 0s 3ms/step - loss: 9.1482e-06
# Epoch 70/100
# 81/81 [==============================] - 0s 3ms/step - loss: 9.5609e-06
# Epoch 71/100
# 81/81 [==============================] - 0s 4ms/step - loss: 9.2452e-06
# Epoch 72/100
# 81/81 [==============================] - 0s 3ms/step - loss: 9.6958e-06
# Epoch 73/100
# 81/81 [==============================] - 0s 3ms/step - loss: 9.5554e-06
# Epoch 74/100
# 81/81 [==============================] - 0s 3ms/step - loss: 9.9788e-06
# Epoch 75/100
# 81/81 [==============================] - 0s 3ms/step - loss: 8.6250e-06
# Epoch 76/100
# 81/81 [==============================] - 0s 3ms/step - loss: 9.7089e-06
# Epoch 77/100
# 81/81 [==============================] - 0s 3ms/step - loss: 1.0357e-05
# Epoch 78/100
# 81/81 [==============================] - 0s 3ms/step - loss: 1.0483e-05
# Epoch 79/100
# 81/81 [==============================] - 0s 3ms/step - loss: 9.2463e-06
# Epoch 80/100
# 81/81 [==============================] - 0s 2ms/step - loss: 8.8908e-06
# Epoch 81/100
# 81/81 [==============================] - 0s 2ms/step - loss: 8.6852e-06
# Epoch 82/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.9150e-06
# Epoch 83/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.4150e-06
# Epoch 84/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.2384e-05
# Epoch 85/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.8558e-06
# Epoch 86/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.5439e-06
# Epoch 87/100
# 81/81 [==============================] - 0s 2ms/step - loss: 8.6841e-06
# Epoch 88/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.4914e-06
# Epoch 89/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.6521e-06
# Epoch 90/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.7893e-06
# Epoch 91/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.1266e-06
# Epoch 92/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.0717e-06
# Epoch 93/100
# 81/81 [==============================] - 0s 2ms/step - loss: 8.8867e-06
# Epoch 94/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.4218e-06
# Epoch 95/100
# 81/81 [==============================] - 0s 2ms/step - loss: 1.0778e-05
# Epoch 96/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.6192e-06
# Epoch 97/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.6037e-06
# Epoch 98/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.4607e-06
# Epoch 99/100
# 81/81 [==============================] - 0s 2ms/step - loss: 8.7896e-06
# Epoch 100/100
# 81/81 [==============================] - 0s 2ms/step - loss: 9.0360e-06
# 20/20 [==============================] - 0s 1ms/step - loss: 2.1800e-05
# 102/102 [==============================] - 0s 1ms/step

# %%
MLP.fit(X_train_hsbc, Y_train_hsbc, epochs=100)
MLP.evaluate(X_test_hsbc, Y_test_hsbc)

X_predict_hsbc,Y_predict = genXY(hsbc_df,10)
X_mlp_hsbc = MLP.predict(X_predict_hsbc)*300
# Out:
# Epoch 1/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9039e-06
# Epoch 2/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0145e-06
# Epoch 3/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0818e-06
# Epoch 4/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7986e-06
# Epoch 5/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8904e-06
# Epoch 6/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8415e-06
# Epoch 7/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8416e-06
# Epoch 8/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.6406e-06
# Epoch 9/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1726e-06
# Epoch 10/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3124e-06
# Epoch 11/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7652e-06
# Epoch 12/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2112e-06
# Epoch 13/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1399e-06
# Epoch 14/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7842e-06
# Epoch 15/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2060e-06
# Epoch 16/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9732e-06
# Epoch 17/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0269e-06
# Epoch 18/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8958e-06
# Epoch 19/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0592e-06
# Epoch 20/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1101e-06
# Epoch 21/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1462e-06
# Epoch 22/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5501e-06
# Epoch 23/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0200e-06
# Epoch 24/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9596e-06
# Epoch 25/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3798e-06
# Epoch 26/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8998e-06
# Epoch 27/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3487e-06
# Epoch 28/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4992e-06
# Epoch 29/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8335e-06
# Epoch 30/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4348e-06
# Epoch 31/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3750e-06
# Epoch 32/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8222e-06
# Epoch 33/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9689e-06
# Epoch 34/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1753e-06
# Epoch 35/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.4679e-06
# Epoch 36/100
# 81/81 [==============================] - 0s 3ms/step - loss: 3.7895e-06
# Epoch 37/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.5304e-06
# Epoch 38/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.0896e-06
# Epoch 39/100
# 81/81 [==============================] - 0s 3ms/step - loss: 3.9952e-06
# Epoch 40/100
# 81/81 [==============================] - 0s 4ms/step - loss: 3.7675e-06
# Epoch 41/100
# 81/81 [==============================] - 0s 3ms/step - loss: 3.9834e-06
# Epoch 42/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.2387e-06
# Epoch 43/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.6861e-06
# Epoch 44/100
# 81/81 [==============================] - 0s 3ms/step - loss: 3.9634e-06
# Epoch 45/100
# 81/81 [==============================] - 0s 3ms/step - loss: 3.6618e-06
# Epoch 46/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9039e-06
# Epoch 47/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2684e-06
# Epoch 48/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3356e-06
# Epoch 49/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4266e-06
# Epoch 50/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8141e-06
# Epoch 51/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1420e-06
# Epoch 52/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8158e-06
# Epoch 53/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1159e-06
# Epoch 54/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9454e-06
# Epoch 55/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8570e-06
# Epoch 56/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7099e-06
# Epoch 57/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7845e-06
# Epoch 58/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7835e-06
# Epoch 59/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9372e-06
# Epoch 60/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9118e-06
# Epoch 61/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1676e-06
# Epoch 62/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1410e-06
# Epoch 63/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.5993e-06
# Epoch 64/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7683e-06
# Epoch 65/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0823e-06
# Epoch 66/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4851e-06
# Epoch 67/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1865e-06
# Epoch 68/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7299e-06
# Epoch 69/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8241e-06
# Epoch 70/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1459e-06
# Epoch 71/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1788e-06
# Epoch 72/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3126e-06
# Epoch 73/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0463e-06
# Epoch 74/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.6568e-06
# Epoch 75/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3286e-06
# Epoch 76/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8692e-06
# Epoch 77/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8326e-06
# Epoch 78/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8864e-06
# Epoch 79/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2425e-06
# Epoch 80/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9698e-06
# Epoch 81/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8547e-06
# Epoch 82/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9889e-06
# Epoch 83/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9394e-06
# Epoch 84/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8290e-06
# Epoch 85/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.9627e-06
# Epoch 86/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8509e-06
# Epoch 87/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7772e-06
# Epoch 88/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4435e-06
# Epoch 89/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.7401e-06
# Epoch 90/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4064e-06
# Epoch 91/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5242e-06
# Epoch 92/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1881e-06
# Epoch 93/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4504e-06
# Epoch 94/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2107e-06
# Epoch 95/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0795e-06
# Epoch 96/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0048e-06
# Epoch 97/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.5594e-06
# Epoch 98/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2763e-06
# Epoch 99/100
# 81/81 [==============================] - 0s 2ms/step - loss: 3.8574e-06
# Epoch 100/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.0539e-06
# 20/20 [==============================] - 0s 2ms/step - loss: 6.0276e-06
# 102/102 [==============================] - 0s 1ms/step

# %%
MLP.fit(X_train_mcd, Y_train_mcd, epochs=100)
MLP.evaluate(X_test_mcd, Y_test_mcd)

X_predict_mcd,Y_predict = genXY(mcd_df,10)
X_mlp_mcd = MLP.predict(X_predict_mcd)*300
# Out:
# Epoch 1/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.4950e-04
# Epoch 2/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.2998e-05
# Epoch 3/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9542e-05
# Epoch 4/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9667e-05
# Epoch 5/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3565e-05
# Epoch 6/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7359e-05
# Epoch 7/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.6295e-05
# Epoch 8/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6053e-05
# Epoch 9/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6857e-05
# Epoch 10/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8412e-05
# Epoch 11/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5502e-05
# Epoch 12/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0296e-05
# Epoch 13/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8247e-05
# Epoch 14/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6389e-05
# Epoch 15/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.5248e-05
# Epoch 16/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3208e-05
# Epoch 17/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4843e-05
# Epoch 18/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6693e-05
# Epoch 19/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.1170e-05
# Epoch 20/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8774e-05
# Epoch 21/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5050e-05
# Epoch 22/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4924e-05
# Epoch 23/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4338e-05
# Epoch 24/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8456e-05
# Epoch 25/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9262e-05
# Epoch 26/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.1572e-05
# Epoch 27/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5838e-05
# Epoch 28/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6141e-05
# Epoch 29/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4370e-05
# Epoch 30/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3680e-05
# Epoch 31/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.2841e-05
# Epoch 32/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5409e-05
# Epoch 33/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4523e-05
# Epoch 34/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0393e-05
# Epoch 35/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9622e-05
# Epoch 36/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3823e-05
# Epoch 37/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4004e-05
# Epoch 38/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4899e-05
# Epoch 39/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4651e-05
# Epoch 40/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0136e-05
# Epoch 41/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4862e-05
# Epoch 42/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0303e-05
# Epoch 43/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8973e-05
# Epoch 44/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7658e-05
# Epoch 45/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.6889e-05
# Epoch 46/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4348e-05
# Epoch 47/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7102e-05
# Epoch 48/100
# 81/81 [==============================] - 0s 2ms/step - loss: 7.1713e-05
# Epoch 49/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7359e-05
# Epoch 50/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7194e-05
# Epoch 51/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9148e-05
# Epoch 52/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3923e-05
# Epoch 53/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4739e-05
# Epoch 54/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4319e-05
# Epoch 55/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9136e-05
# Epoch 56/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.4458e-05
# Epoch 57/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.8684e-05
# Epoch 58/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.8824e-05
# Epoch 59/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.3513e-05
# Epoch 60/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.5139e-05
# Epoch 61/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.3660e-05
# Epoch 62/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.5296e-05
# Epoch 63/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.3911e-05
# Epoch 64/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.3104e-05
# Epoch 65/100
# 81/81 [==============================] - 0s 3ms/step - loss: 5.6001e-05
# Epoch 66/100
# 81/81 [==============================] - 0s 4ms/step - loss: 6.1820e-05
# Epoch 67/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.1213e-05
# Epoch 68/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0007e-05
# Epoch 69/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6872e-05
# Epoch 70/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6279e-05
# Epoch 71/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.0499e-05
# Epoch 72/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6732e-05
# Epoch 73/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4761e-05
# Epoch 74/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.5934e-05
# Epoch 75/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.9946e-05
# Epoch 76/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1940e-05
# Epoch 77/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3080e-05
# Epoch 78/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5802e-05
# Epoch 79/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3260e-05
# Epoch 80/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6992e-05
# Epoch 81/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7655e-05
# Epoch 82/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.5510e-05
# Epoch 83/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.2293e-05
# Epoch 84/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.2589e-05
# Epoch 85/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1946e-05
# Epoch 86/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8975e-05
# Epoch 87/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6847e-05
# Epoch 88/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.3391e-05
# Epoch 89/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4106e-05
# Epoch 90/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8290e-05
# Epoch 91/100
# 81/81 [==============================] - 0s 2ms/step - loss: 6.5282e-05
# Epoch 92/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.2507e-05
# Epoch 93/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3818e-05
# Epoch 94/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.7602e-05
# Epoch 95/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.3262e-05
# Epoch 96/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.2433e-05
# Epoch 97/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.8572e-05
# Epoch 98/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4039e-05
# Epoch 99/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6605e-05
# Epoch 100/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.6904e-05
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5062e-04
# 102/102 [==============================] - 0s 1ms/step

# %%
MLP.fit(X_train_nike, Y_train_nike, epochs=100)
MLP.evaluate(X_test_nike, Y_test_nike)

X_predict_nike,Y_predict = genXY(nike_df,10)
X_mlp_nike = MLP.predict(X_predict_nike)*300
# Out:
# Epoch 1/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.6420e-05
# Epoch 2/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1628e-05
# Epoch 3/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2525e-05
# Epoch 4/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1694e-05
# Epoch 5/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1542e-05
# Epoch 6/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.2165e-05
# Epoch 7/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1488e-05
# Epoch 8/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.2278e-05
# Epoch 9/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1358e-05
# Epoch 10/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1216e-05
# Epoch 11/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.0927e-05
# Epoch 12/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1998e-05
# Epoch 13/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1260e-05
# Epoch 14/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1207e-05
# Epoch 15/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1650e-05
# Epoch 16/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1597e-05
# Epoch 17/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3180e-05
# Epoch 18/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2470e-05
# Epoch 19/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2289e-05
# Epoch 20/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2544e-05
# Epoch 21/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2639e-05
# Epoch 22/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.0834e-05
# Epoch 23/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1221e-05
# Epoch 24/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2132e-05
# Epoch 25/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2749e-05
# Epoch 26/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3010e-05
# Epoch 27/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2551e-05
# Epoch 28/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2072e-05
# Epoch 29/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3704e-05
# Epoch 30/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1553e-05
# Epoch 31/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1370e-05
# Epoch 32/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2848e-05
# Epoch 33/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1986e-05
# Epoch 34/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.4327e-05
# Epoch 35/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1413e-05
# Epoch 36/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2884e-05
# Epoch 37/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.5851e-05
# Epoch 38/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3589e-05
# Epoch 39/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3947e-05
# Epoch 40/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3988e-05
# Epoch 41/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3335e-05
# Epoch 42/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1517e-05
# Epoch 43/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1835e-05
# Epoch 44/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2255e-05
# Epoch 45/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1860e-05
# Epoch 46/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2086e-05
# Epoch 47/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2621e-05
# Epoch 48/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3935e-05
# Epoch 49/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2207e-05
# Epoch 50/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.5187e-05
# Epoch 51/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1628e-05
# Epoch 52/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2592e-05
# Epoch 53/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.5182e-05
# Epoch 54/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2663e-05
# Epoch 55/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.4020e-05
# Epoch 56/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2493e-05
# Epoch 57/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.4303e-05
# Epoch 58/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.4163e-05
# Epoch 59/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2933e-05
# Epoch 60/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2001e-05
# Epoch 61/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3169e-05
# Epoch 62/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.5766e-05
# Epoch 63/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2214e-05
# Epoch 64/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.4798e-05
# Epoch 65/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2729e-05
# Epoch 66/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.5227e-05
# Epoch 67/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1882e-05
# Epoch 68/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3418e-05
# Epoch 69/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2607e-05
# Epoch 70/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2041e-05
# Epoch 71/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2500e-05
# Epoch 72/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1914e-05
# Epoch 73/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1222e-05
# Epoch 74/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2350e-05
# Epoch 75/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1715e-05
# Epoch 76/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.6307e-05
# Epoch 77/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1210e-05
# Epoch 78/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.3220e-05
# Epoch 79/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.2396e-05
# Epoch 80/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1898e-05
# Epoch 81/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.2260e-05
# Epoch 82/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.7291e-05
# Epoch 83/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.3163e-05
# Epoch 84/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.5864e-05
# Epoch 85/100
# 81/81 [==============================] - 0s 3ms/step - loss: 2.1653e-05
# Epoch 86/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1334e-05
# Epoch 87/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2090e-05
# Epoch 88/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2233e-05
# Epoch 89/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3662e-05
# Epoch 90/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1545e-05
# Epoch 91/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2398e-05
# Epoch 92/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3816e-05
# Epoch 93/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2750e-05
# Epoch 94/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3557e-05
# Epoch 95/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3042e-05
# Epoch 96/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.3494e-05
# Epoch 97/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2637e-05
# Epoch 98/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2623e-05
# Epoch 99/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.2676e-05
# Epoch 100/100
# 81/81 [==============================] - 0s 2ms/step - loss: 2.1827e-05
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5163e-04
# 102/102 [==============================] - 0s 1ms/step

# %%
MLP.fit(X_train_tm, Y_train_tm, epochs=100)
MLP.evaluate(X_test_tm, Y_test_tm)

X_predict_tm,Y_predict = genXY(tm_df,10)
X_mlp_tm = MLP.predict(X_predict_tm)*300
# Out:
# Epoch 1/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1034e-05
# Epoch 2/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.2231e-05
# Epoch 3/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7809e-05
# Epoch 4/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7526e-05
# Epoch 5/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4805e-05
# Epoch 6/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.8949e-05
# Epoch 7/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1357e-05
# Epoch 8/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.0894e-05
# Epoch 9/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3455e-05
# Epoch 10/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5357e-05
# Epoch 11/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3661e-05
# Epoch 12/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5704e-05
# Epoch 13/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.9047e-05
# Epoch 14/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.9759e-05
# Epoch 15/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3923e-05
# Epoch 16/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.8176e-05
# Epoch 17/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.1384e-05
# Epoch 18/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7070e-05
# Epoch 19/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3807e-05
# Epoch 20/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3571e-05
# Epoch 21/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6027e-05
# Epoch 22/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5710e-05
# Epoch 23/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4358e-05
# Epoch 24/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5220e-05
# Epoch 25/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5629e-05
# Epoch 26/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5979e-05
# Epoch 27/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6390e-05
# Epoch 28/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5426e-05
# Epoch 29/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.8514e-05
# Epoch 30/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.9077e-05
# Epoch 31/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.5820e-05
# Epoch 32/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.5143e-05
# Epoch 33/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.4269e-05
# Epoch 34/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.7472e-05
# Epoch 35/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.6830e-05
# Epoch 36/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.4394e-05
# Epoch 37/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.5161e-05
# Epoch 38/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.4833e-05
# Epoch 39/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.5682e-05
# Epoch 40/100
# 81/81 [==============================] - 0s 3ms/step - loss: 4.4388e-05
# Epoch 41/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5238e-05
# Epoch 42/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7775e-05
# Epoch 43/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4483e-05
# Epoch 44/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.8511e-05
# Epoch 45/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4307e-05
# Epoch 46/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4434e-05
# Epoch 47/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4842e-05
# Epoch 48/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6223e-05
# Epoch 49/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2390e-05
# Epoch 50/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6334e-05
# Epoch 51/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3660e-05
# Epoch 52/100
# 81/81 [==============================] - 0s 2ms/step - loss: 5.4675e-05
# Epoch 53/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6740e-05
# Epoch 54/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6212e-05
# Epoch 55/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3766e-05
# Epoch 56/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4200e-05
# Epoch 57/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6643e-05
# Epoch 58/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4210e-05
# Epoch 59/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.8523e-05
# Epoch 60/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3957e-05
# Epoch 61/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3258e-05
# Epoch 62/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4844e-05
# Epoch 63/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5321e-05
# Epoch 64/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6517e-05
# Epoch 65/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2355e-05
# Epoch 66/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5314e-05
# Epoch 67/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2477e-05
# Epoch 68/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5776e-05
# Epoch 69/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5320e-05
# Epoch 70/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3588e-05
# Epoch 71/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1817e-05
# Epoch 72/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4193e-05
# Epoch 73/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2933e-05
# Epoch 74/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4387e-05
# Epoch 75/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5930e-05
# Epoch 76/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5998e-05
# Epoch 77/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6776e-05
# Epoch 78/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4478e-05
# Epoch 79/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6967e-05
# Epoch 80/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3230e-05
# Epoch 81/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4818e-05
# Epoch 82/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7951e-05
# Epoch 83/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5758e-05
# Epoch 84/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4343e-05
# Epoch 85/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7168e-05
# Epoch 86/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7296e-05
# Epoch 87/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5520e-05
# Epoch 88/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.1873e-05
# Epoch 89/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6729e-05
# Epoch 90/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.2964e-05
# Epoch 91/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5228e-05
# Epoch 92/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.3302e-05
# Epoch 93/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4827e-05
# Epoch 94/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4624e-05
# Epoch 95/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.6709e-05
# Epoch 96/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.7615e-05
# Epoch 97/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.9517e-05
# Epoch 98/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.4271e-05
# Epoch 99/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.5731e-05
# Epoch 100/100
# 81/81 [==============================] - 0s 2ms/step - loss: 4.9207e-05
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5749e-04
# 102/102 [==============================] - 0s 2ms/step

# %% [markdown]
# Original data

# %%
azn_og=np.array(azn_df)
azn_og=azn_og[9:]

intel_og=np.array(intel_df)
intel_og=intel_og[9:]

hsbc_og=np.array(hsbc_df)
hsbc_og=hsbc_og[9:]

mcd_og=np.array(mcd_df)
mcd_og=mcd_og[9:]

nike_og=np.array(nike_df)
nike_og=nike_og[9:]

tm_og=np.array(tm_df)
tm_og=tm_og[9:]

# %% [markdown]
# Comparing results on plots

# %%
plt.plot(X_mlp_azn, label='Astra Zeneca Prediction')
plt.plot(azn_og, label='Original')
plt.legend()

# %%
plt.plot(X_mlp_intel, label='Intel Prediction')
plt.plot(intel_og, label='Original')
plt.legend()

# %%
plt.plot(X_mlp_hsbc, label='HSBC Prediction')
plt.plot(hsbc_og, label='Original')
plt.legend()

# %%
plt.plot(X_mlp_mcd, label='McDonalds Prediction')
plt.plot(mcd_og, label='Original')
plt.legend()

# %%
plt.plot(X_mlp_nike, label='Nike Prediction')
plt.plot(nike_og, label='Original')
plt.legend()

# %%
plt.plot(X_mlp_tm, label='Toyota Prediction')
plt.plot(tm_og, label='Original')
plt.legend()

# %% [markdown]
# More detailed plots in selected period

# %%
plt.plot(X_mlp_azn[3000:], label='Astra Zeneca Prediction')
plt.plot(azn_og[3000:], label='Original')
plt.legend()

# %%
plt.plot(X_mlp_intel[3000:], label='Intel Prediction')
plt.plot(intel_og[3000:], label='Original')
plt.legend()

# %%
plt.plot(X_mlp_hsbc[3000:], label='HSBC Prediction')
plt.plot(hsbc_og[3000:], label='Original')
plt.legend()

# %%
plt.plot(X_mlp_mcd[3000:], label='McDonalds Prediction')
plt.plot(mcd_og[3000:], label='Original')
plt.legend()

# %%
plt.plot(X_mlp_nike[3000:], label='Nike Prediction')
plt.plot(nike_og[3000:], label='Original')
plt.legend()

# %%
plt.plot(X_mlp_tm[3000:], label='Toyota Prediction')
plt.plot(tm_og[3000:], label='Original')
plt.legend()

# %% [markdown]
# ##LSTM

# %%
LSTM = tf.keras.Sequential()
LSTM.add(tf.keras.layers.LSTM(20, input_shape=(10, 1), return_sequences=True))
LSTM.add(tf.keras.layers.LSTM(20))
LSTM.add(tf.keras.layers.Dense(1, activation=tf.nn.relu))

LSTM.compile(optimizer="adam", loss="mean_squared_error")

# %%
LSTM.fit(X_train_azn, Y_train_azn, epochs=50)
LSTM.evaluate(X_test_azn, Y_test_azn)

X_lstm_azn,Y_lstm = genXY(azn_df,10)
X_lstm_azn_end = LSTM.predict(X_lstm_azn)*300
# Out:
# Epoch 1/50
# 81/81 [==============================] - 5s 12ms/step - loss: 7.2206e-04
# Epoch 2/50
# 81/81 [==============================] - 1s 17ms/step - loss: 1.1474e-05
# Epoch 3/50
# 81/81 [==============================] - 1s 16ms/step - loss: 1.1292e-05
# Epoch 4/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1300e-05
# Epoch 5/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1179e-05
# Epoch 6/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.1663e-05
# Epoch 7/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.1320e-05
# Epoch 8/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.1397e-05
# Epoch 9/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1902e-05
# Epoch 10/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0968e-05
# Epoch 11/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1195e-05
# Epoch 12/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1741e-05
# Epoch 13/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0492e-05
# Epoch 14/50
# 81/81 [==============================] - 1s 14ms/step - loss: 1.1358e-05
# Epoch 15/50
# 81/81 [==============================] - 1s 16ms/step - loss: 1.1049e-05
# Epoch 16/50
# 81/81 [==============================] - 1s 16ms/step - loss: 1.0550e-05
# Epoch 17/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.1571e-05
# Epoch 18/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.2471e-05
# Epoch 19/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0639e-05
# Epoch 20/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.2048e-05
# Epoch 21/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0975e-05
# Epoch 22/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0811e-05
# Epoch 23/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0689e-05
# Epoch 24/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0655e-05
# Epoch 25/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.1051e-05
# Epoch 26/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.0555e-05
# Epoch 27/50
# 81/81 [==============================] - 1s 16ms/step - loss: 1.0318e-05
# Epoch 28/50
# 81/81 [==============================] - 1s 17ms/step - loss: 1.0162e-05
# Epoch 29/50
# 81/81 [==============================] - 1s 13ms/step - loss: 1.0014e-05
# Epoch 30/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0584e-05
# Epoch 31/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0473e-05
# Epoch 32/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0543e-05
# Epoch 33/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0109e-05
# Epoch 34/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1190e-05
# Epoch 35/50
# 81/81 [==============================] - 1s 11ms/step - loss: 9.5969e-06
# Epoch 36/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.0313e-05
# Epoch 37/50
# 81/81 [==============================] - 1s 12ms/step - loss: 9.7866e-06
# Epoch 38/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0484e-05
# Epoch 39/50
# 81/81 [==============================] - 1s 13ms/step - loss: 1.0520e-05
# Epoch 40/50
# 81/81 [==============================] - 1s 17ms/step - loss: 1.0157e-05
# Epoch 41/50
# 81/81 [==============================] - 1s 16ms/step - loss: 9.7741e-06
# Epoch 42/50
# 81/81 [==============================] - 1s 12ms/step - loss: 9.5038e-06
# Epoch 43/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0358e-05
# Epoch 44/50
# 81/81 [==============================] - 1s 12ms/step - loss: 9.2927e-06
# Epoch 45/50
# 81/81 [==============================] - 1s 11ms/step - loss: 9.1818e-06
# Epoch 46/50
# 81/81 [==============================] - 1s 12ms/step - loss: 9.8687e-06
# Epoch 47/50
# 81/81 [==============================] - 1s 12ms/step - loss: 9.7732e-06
# Epoch 48/50
# 81/81 [==============================] - 1s 12ms/step - loss: 9.0646e-06
# Epoch 49/50
# 81/81 [==============================] - 1s 12ms/step - loss: 8.9433e-06
# Epoch 50/50
# 81/81 [==============================] - 1s 12ms/step - loss: 9.0609e-06
# 20/20 [==============================] - 1s 4ms/step - loss: 4.8276e-05
# 102/102 [==============================] - 1s 4ms/step

# %%
LSTM.fit(X_train_intel, Y_train_intel, epochs=50)
LSTM.evaluate(X_test_intel, Y_test_intel)

X_lstm_intel,Y_lstm = genXY(intel_df,10)
X_lstm_intel_end = LSTM.predict(X_lstm_intel)*300
# Out:
# Epoch 1/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.2441e-05
# Epoch 2/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.8494e-05
# Epoch 3/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.7944e-05
# Epoch 4/50
# 81/81 [==============================] - 2s 21ms/step - loss: 1.9102e-05
# Epoch 5/50
# 81/81 [==============================] - 2s 24ms/step - loss: 1.6584e-05
# Epoch 6/50
# 81/81 [==============================] - 2s 24ms/step - loss: 1.6687e-05
# Epoch 7/50
# 81/81 [==============================] - 2s 19ms/step - loss: 1.8214e-05
# Epoch 8/50
# 81/81 [==============================] - 2s 24ms/step - loss: 1.5949e-05
# Epoch 9/50
# 81/81 [==============================] - 2s 22ms/step - loss: 1.6865e-05
# Epoch 10/50
# 81/81 [==============================] - 2s 25ms/step - loss: 1.7601e-05
# Epoch 11/50
# 81/81 [==============================] - 2s 23ms/step - loss: 1.5901e-05
# Epoch 12/50
# 81/81 [==============================] - 1s 17ms/step - loss: 1.4156e-05
# Epoch 13/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.5787e-05
# Epoch 14/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.3925e-05
# Epoch 15/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.7794e-05
# Epoch 16/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.3678e-05
# Epoch 17/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.5548e-05
# Epoch 18/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.6464e-05
# Epoch 19/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.3705e-05
# Epoch 20/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.4265e-05
# Epoch 21/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.4994e-05
# Epoch 22/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.3023e-05
# Epoch 23/50
# 81/81 [==============================] - 1s 13ms/step - loss: 1.2833e-05
# Epoch 24/50
# 81/81 [==============================] - 1s 17ms/step - loss: 1.3484e-05
# Epoch 25/50
# 81/81 [==============================] - 1s 15ms/step - loss: 1.2522e-05
# Epoch 26/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.3040e-05
# Epoch 27/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.4170e-05
# Epoch 28/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.2867e-05
# Epoch 29/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.2711e-05
# Epoch 30/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.1996e-05
# Epoch 31/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.2801e-05
# Epoch 32/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1858e-05
# Epoch 33/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1426e-05
# Epoch 34/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1754e-05
# Epoch 35/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1197e-05
# Epoch 36/50
# 81/81 [==============================] - 1s 15ms/step - loss: 1.2557e-05
# Epoch 37/50
# 81/81 [==============================] - 1s 17ms/step - loss: 1.2091e-05
# Epoch 38/50
# 81/81 [==============================] - 1s 13ms/step - loss: 1.1276e-05
# Epoch 39/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.2247e-05
# Epoch 40/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1157e-05
# Epoch 41/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1523e-05
# Epoch 42/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1064e-05
# Epoch 43/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0801e-05
# Epoch 44/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.0407e-05
# Epoch 45/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.0585e-05
# Epoch 46/50
# 81/81 [==============================] - 1s 12ms/step - loss: 1.1118e-05
# Epoch 47/50
# 81/81 [==============================] - 1s 11ms/step - loss: 1.0535e-05
# Epoch 48/50
# 81/81 [==============================] - 1s 13ms/step - loss: 1.0522e-05
# Epoch 49/50
# 81/81 [==============================] - 1s 17ms/step - loss: 1.0095e-05
# Epoch 50/50
# 81/81 [==============================] - 1s 16ms/step - loss: 1.0297e-05
# 20/20 [==============================] - 0s 4ms/step - loss: 2.8951e-05
# 102/102 [==============================] - 0s 4ms/step

# %%
LSTM.fit(X_train_hsbc, Y_train_hsbc, epochs=50)
LSTM.evaluate(X_test_hsbc, Y_test_hsbc)

X_lstm_hsbc,Y_lstm = genXY(hsbc_df,10)
X_lstm_hsbc_end = LSTM.predict(X_lstm_hsbc)*300
# Out:
# Epoch 1/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.6265e-06
# Epoch 2/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.3858e-06
# Epoch 3/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2261e-06
# Epoch 4/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4565e-06
# Epoch 5/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.3422e-06
# Epoch 6/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2429e-06
# Epoch 7/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2589e-06
# Epoch 8/50
# 81/81 [==============================] - 1s 11ms/step - loss: 3.9308e-06
# Epoch 9/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.1201e-06
# Epoch 10/50
# 81/81 [==============================] - 1s 15ms/step - loss: 4.5193e-06
# Epoch 11/50
# 81/81 [==============================] - 1s 17ms/step - loss: 4.6519e-06
# Epoch 12/50
# 81/81 [==============================] - 1s 13ms/step - loss: 4.0955e-06
# Epoch 13/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.5710e-06
# Epoch 14/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.7200e-06
# Epoch 15/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.1820e-06
# Epoch 16/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2399e-06
# Epoch 17/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.1055e-06
# Epoch 18/50
# 81/81 [==============================] - 1s 11ms/step - loss: 3.9221e-06
# Epoch 19/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2522e-06
# Epoch 20/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4665e-06
# Epoch 21/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.3325e-06
# Epoch 22/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3761e-06
# Epoch 23/50
# 81/81 [==============================] - 1s 17ms/step - loss: 4.2484e-06
# Epoch 24/50
# 81/81 [==============================] - 1s 16ms/step - loss: 4.1830e-06
# Epoch 25/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.3189e-06
# Epoch 26/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.1828e-06
# Epoch 27/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2426e-06
# Epoch 28/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.0167e-06
# Epoch 29/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.0017e-06
# Epoch 30/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.6146e-06
# Epoch 31/50
# 81/81 [==============================] - 1s 11ms/step - loss: 3.9301e-06
# Epoch 32/50
# 81/81 [==============================] - 1s 11ms/step - loss: 3.8727e-06
# Epoch 33/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.5219e-06
# Epoch 34/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.3643e-06
# Epoch 35/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3496e-06
# Epoch 36/50
# 81/81 [==============================] - 1s 16ms/step - loss: 3.8299e-06
# Epoch 37/50
# 81/81 [==============================] - 1s 16ms/step - loss: 4.1115e-06
# Epoch 38/50
# 81/81 [==============================] - 1s 11ms/step - loss: 3.9378e-06
# Epoch 39/50
# 81/81 [==============================] - 1s 12ms/step - loss: 3.8864e-06
# Epoch 40/50
# 81/81 [==============================] - 1s 12ms/step - loss: 3.9812e-06
# Epoch 41/50
# 81/81 [==============================] - 1s 11ms/step - loss: 3.9284e-06
# Epoch 42/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.3834e-06
# Epoch 43/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.1033e-06
# Epoch 44/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.0192e-06
# Epoch 45/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.0844e-06
# Epoch 46/50
# 81/81 [==============================] - 1s 11ms/step - loss: 3.8332e-06
# Epoch 47/50
# 81/81 [==============================] - 1s 11ms/step - loss: 3.9816e-06
# Epoch 48/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.0351e-06
# Epoch 49/50
# 81/81 [==============================] - 1s 16ms/step - loss: 3.7459e-06
# Epoch 50/50
# 81/81 [==============================] - 1s 17ms/step - loss: 3.9142e-06
# 20/20 [==============================] - 0s 4ms/step - loss: 5.7245e-06
# 102/102 [==============================] - 0s 4ms/step

# %%
LSTM.fit(X_train_mcd, Y_train_mcd, epochs=50)
LSTM.evaluate(X_test_mcd, Y_test_mcd)

X_lstm_mcd,Y_lstm = genXY(mcd_df,10)
X_lstm_mcd_end = LSTM.predict(X_lstm_mcd)*300
# Out:
# Epoch 1/50
# 81/81 [==============================] - 1s 15ms/step - loss: 1.5998e-04
# Epoch 2/50
# 81/81 [==============================] - 1s 16ms/step - loss: 5.4752e-05
# Epoch 3/50
# 81/81 [==============================] - 1s 14ms/step - loss: 5.5423e-05
# Epoch 4/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.6376e-05
# Epoch 5/50
# 81/81 [==============================] - 1s 11ms/step - loss: 6.0629e-05
# Epoch 6/50
# 81/81 [==============================] - 1s 12ms/step - loss: 6.5415e-05
# Epoch 7/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.6736e-05
# Epoch 8/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.6552e-05
# Epoch 9/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.5309e-05
# Epoch 10/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.8991e-05
# Epoch 11/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.3912e-05
# Epoch 12/50
# 81/81 [==============================] - 1s 12ms/step - loss: 6.0413e-05
# Epoch 13/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.6058e-05
# Epoch 14/50
# 81/81 [==============================] - 1s 15ms/step - loss: 5.3547e-05
# Epoch 15/50
# 81/81 [==============================] - 1s 17ms/step - loss: 5.4736e-05
# Epoch 16/50
# 81/81 [==============================] - 1s 14ms/step - loss: 5.1514e-05
# Epoch 17/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.2080e-05
# Epoch 18/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.2481e-05
# Epoch 19/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.1358e-05
# Epoch 20/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.7485e-05
# Epoch 21/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.6910e-05
# Epoch 22/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.3030e-05
# Epoch 23/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.3631e-05
# Epoch 24/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.4288e-05
# Epoch 25/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.4232e-05
# Epoch 26/50
# 81/81 [==============================] - 1s 12ms/step - loss: 6.0718e-05
# Epoch 27/50
# 81/81 [==============================] - 1s 17ms/step - loss: 5.7089e-05
# Epoch 28/50
# 81/81 [==============================] - 1s 17ms/step - loss: 5.4516e-05
# Epoch 29/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.5490e-05
# Epoch 30/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.6958e-05
# Epoch 31/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.4016e-05
# Epoch 32/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.8725e-05
# Epoch 33/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.4280e-05
# Epoch 34/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.1945e-05
# Epoch 35/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.2390e-05
# Epoch 36/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.1813e-05
# Epoch 37/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.6091e-05
# Epoch 38/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.4890e-05
# Epoch 39/50
# 81/81 [==============================] - 1s 14ms/step - loss: 5.5075e-05
# Epoch 40/50
# 81/81 [==============================] - 1s 16ms/step - loss: 5.4342e-05
# Epoch 41/50
# 81/81 [==============================] - 1s 14ms/step - loss: 5.5403e-05
# Epoch 42/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.3049e-05
# Epoch 43/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.4932e-05
# Epoch 44/50
# 81/81 [==============================] - 1s 11ms/step - loss: 6.1251e-05
# Epoch 45/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.2483e-05
# Epoch 46/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.3622e-05
# Epoch 47/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.6000e-05
# Epoch 48/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.6724e-05
# Epoch 49/50
# 81/81 [==============================] - 1s 11ms/step - loss: 5.1337e-05
# Epoch 50/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.6325e-05
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6755e-04
# 102/102 [==============================] - 0s 4ms/step

# %%
LSTM.fit(X_train_nike, Y_train_nike, epochs=50)
LSTM.evaluate(X_test_nike, Y_test_nike)

X_lstm_nike,Y_lstm = genXY(nike_df,10)
X_lstm_nike_end = LSTM.predict(X_lstm_nike)*300
# Out:
# Epoch 1/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.0414e-05
# Epoch 2/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1325e-05
# Epoch 3/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.0606e-05
# Epoch 4/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1618e-05
# Epoch 5/50
# 81/81 [==============================] - 1s 17ms/step - loss: 2.0942e-05
# Epoch 6/50
# 81/81 [==============================] - 1s 16ms/step - loss: 2.1395e-05
# Epoch 7/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1416e-05
# Epoch 8/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1497e-05
# Epoch 9/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.1319e-05
# Epoch 10/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.2238e-05
# Epoch 11/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.0888e-05
# Epoch 12/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.0678e-05
# Epoch 13/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.0824e-05
# Epoch 14/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.0581e-05
# Epoch 15/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.1676e-05
# Epoch 16/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.1648e-05
# Epoch 17/50
# 81/81 [==============================] - 1s 13ms/step - loss: 2.1753e-05
# Epoch 18/50
# 81/81 [==============================] - 1s 16ms/step - loss: 2.1490e-05
# Epoch 19/50
# 81/81 [==============================] - 1s 16ms/step - loss: 2.1571e-05
# Epoch 20/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.1093e-05
# Epoch 21/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.0978e-05
# Epoch 22/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.1440e-05
# Epoch 23/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.1210e-05
# Epoch 24/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.4077e-05
# Epoch 25/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.2093e-05
# Epoch 26/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1338e-05
# Epoch 27/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1222e-05
# Epoch 28/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.0911e-05
# Epoch 29/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.2007e-05
# Epoch 30/50
# 81/81 [==============================] - 1s 13ms/step - loss: 2.3127e-05
# Epoch 31/50
# 81/81 [==============================] - 1s 16ms/step - loss: 2.1992e-05
# Epoch 32/50
# 81/81 [==============================] - 1s 16ms/step - loss: 2.2140e-05
# Epoch 33/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.2713e-05
# Epoch 34/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.3549e-05
# Epoch 35/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.3340e-05
# Epoch 36/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.2279e-05
# Epoch 37/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.1202e-05
# Epoch 38/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.0903e-05
# Epoch 39/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.0880e-05
# Epoch 40/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.5426e-05
# Epoch 41/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.3643e-05
# Epoch 42/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1163e-05
# Epoch 43/50
# 81/81 [==============================] - 1s 13ms/step - loss: 2.2574e-05
# Epoch 44/50
# 81/81 [==============================] - 1s 17ms/step - loss: 2.1162e-05
# Epoch 45/50
# 81/81 [==============================] - 1s 16ms/step - loss: 2.2429e-05
# Epoch 46/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.1686e-05
# Epoch 47/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1538e-05
# Epoch 48/50
# 81/81 [==============================] - 1s 11ms/step - loss: 2.4443e-05
# Epoch 49/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.1019e-05
# Epoch 50/50
# 81/81 [==============================] - 1s 12ms/step - loss: 2.2497e-05
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4680e-04
# 102/102 [==============================] - 0s 4ms/step

# %%
LSTM.fit(X_train_tm, Y_train_tm, epochs=50)
LSTM.evaluate(X_test_tm, Y_test_tm)

X_lstm_tm,Y_lstm = genXY(tm_df,10)
X_lstm_tm_end = LSTM.predict(X_lstm_tm)*300
# Out:
# Epoch 1/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.4084e-05
# Epoch 2/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.6266e-05
# Epoch 3/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.8566e-05
# Epoch 4/50
# 81/81 [==============================] - 1s 12ms/step - loss: 5.1579e-05
# Epoch 5/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2927e-05
# Epoch 6/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.4768e-05
# Epoch 7/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3650e-05
# Epoch 8/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.4539e-05
# Epoch 9/50
# 81/81 [==============================] - 1s 16ms/step - loss: 4.2216e-05
# Epoch 10/50
# 81/81 [==============================] - 1s 16ms/step - loss: 4.4917e-05
# Epoch 11/50
# 81/81 [==============================] - 1s 13ms/step - loss: 4.2246e-05
# Epoch 12/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.6610e-05
# Epoch 13/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3582e-05
# Epoch 14/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2259e-05
# Epoch 15/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4111e-05
# Epoch 16/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4246e-05
# Epoch 17/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.5672e-05
# Epoch 18/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.3141e-05
# Epoch 19/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.2406e-05
# Epoch 20/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.4188e-05
# Epoch 21/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4758e-05
# Epoch 22/50
# 81/81 [==============================] - 1s 17ms/step - loss: 4.5686e-05
# Epoch 23/50
# 81/81 [==============================] - 1s 16ms/step - loss: 4.5945e-05
# Epoch 24/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.4114e-05
# Epoch 25/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.3833e-05
# Epoch 26/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4928e-05
# Epoch 27/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4495e-05
# Epoch 28/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.2293e-05
# Epoch 29/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3696e-05
# Epoch 30/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3058e-05
# Epoch 31/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3694e-05
# Epoch 32/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.5096e-05
# Epoch 33/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.3778e-05
# Epoch 34/50
# 81/81 [==============================] - 1s 14ms/step - loss: 4.4030e-05
# Epoch 35/50
# 81/81 [==============================] - 1s 17ms/step - loss: 4.4899e-05
# Epoch 36/50
# 81/81 [==============================] - 1s 14ms/step - loss: 4.6975e-05
# Epoch 37/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4162e-05
# Epoch 38/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.6284e-05
# Epoch 39/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4069e-05
# Epoch 40/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4135e-05
# Epoch 41/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.4378e-05
# Epoch 42/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.6113e-05
# Epoch 43/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3708e-05
# Epoch 44/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.2879e-05
# Epoch 45/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.2499e-05
# Epoch 46/50
# 81/81 [==============================] - 1s 11ms/step - loss: 4.1701e-05
# Epoch 47/50
# 81/81 [==============================] - 1s 16ms/step - loss: 4.2020e-05
# Epoch 48/50
# 81/81 [==============================] - 1s 16ms/step - loss: 4.3276e-05
# Epoch 49/50
# 81/81 [==============================] - 1s 14ms/step - loss: 4.3512e-05
# Epoch 50/50
# 81/81 [==============================] - 1s 12ms/step - loss: 4.3023e-05
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4642e-04
# 102/102 [==============================] - 0s 4ms/step

# %% [markdown]
# Plots

# %%
plt.plot(X_lstm_azn_end[1000:1100], label='Astra Zeneca Prediction')
plt.plot(azn_og[1000:1100], label='Original')
plt.legend()

# %%
plt.plot(X_lstm_intel_end[1000:1100], label='Intel Prediction')
plt.plot(intel_og[1000:1100], label='Original')
plt.legend()

# %%
plt.plot(X_lstm_hsbc_end[1000:1100], label='HSBC Prediction')
plt.plot(hsbc_og[1000:1100], label='Original')
plt.legend()

# %%
plt.plot(X_lstm_mcd_end[1000:1100], label='McDonalds Prediction')
plt.plot(mcd_og[1000:1100], label='Original')
plt.legend()

# %%
plt.plot(X_lstm_nike_end[1000:1100], label='Nike Prediction')
plt.plot(nike_og[1000:1100], label='Original')
plt.legend()

# %%
plt.plot(X_lstm_tm_end[1000:1100], label='Toyota Prediction')
plt.plot(tm_og[1000:1100], label='Original')
plt.legend()
